# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
PLAY_BY_PLAY_DATASET_FILE_DIR = '../../datasets/original-data/Copia de playByplay-2023-05-10T20_05_08.442+02_00.csv'

# %%
play_by_play_dataset = pd.read_csv(PLAY_BY_PLAY_DATASET_FILE_DIR,sep='\t')
play_by_play_dataset.head()
# Out:
#                       Game      Start        End  Period         Team  \
# 0   BERABERA vs GRANOLLERS   00:00:00   00:00:00      T1   GRANOLLERS
# 1   BERABERA vs GRANOLLERS   00:00:00   00:00:36      T1   GRANOLLERS
# 2   BERABERA vs GRANOLLERS   00:00:36   00:00:45      T1   GRANOLLERS
# 3   BERABERA vs GRANOLLERS   00:00:45   00:00:55      T1     BERABERA
# 4   BERABERA vs GRANOLLERS   00:00:55   00:01:24      T1   GRANOLLERS
#
#                Event                Phase  Offense System  Defense System  \
# 0   FIRST_HALF_START   OFFENSE_POSITIONAL        EQUALITY             6:0
# 1       FOUL_RECEIVE   OFFENSE_POSITIONAL        EQUALITY             5:1
# 2           POST_OUT   OFFENSE_POSITIONAL        EQUALITY             5:1
# 3          LOST_BALL           FAST_BREAK        EQUALITY             6:0
# 4       FOUL_RECEIVE   OFFENSE_POSITIONAL        EQUALITY             5:1
#
#    Assist  Offense Player Number  Offense Player Name  \
# 0
# ...

# %% [markdown]
# Arrojería, en el partido, da un total de 7 asistencias, que se van a añadir en el campo Assist del gol que asiste.

# %%
play_by_play_dataset[play_by_play_dataset[' Start'] == ' 00:12:46']
# Out:
#                       Game      Start        End  Period       Team  Event  \
# 40  BERABERA vs GRANOLLERS   00:12:46   00:13:20      T1   BERABERA   GOAL
#
#                   Phase  Offense System  Defense System  Assist  \
# 40   OFFENSE_POSITIONAL        EQUALITY             6:0
#
#     Offense Player Number  Offense Player Name  Offense Player Position  \
# 40                     14            14-M.CAVO                       rb
#
#     Defense Player Number  Defense Player Name  Defense Player Position  \
# 40                      1        01-N. WIGGINS                       gk
#
#     Shooter Position  Shot Location  \
# 40          RIGHT_6M              4
#
#                                             Home Team  \
# 40   15-M. ECHEVERRIA, 14-M.CAVO, 42-C.POLONIO, 13...
#
#                                          Visitor Team   Possession  \
# 40   17-E.SOMAZA, 23-A.GONZALEZ, 22-P.MILAGROS, 14...           13
#
#      Important   Game System
# 40       False           NaN

# %%
play_by_play_dataset.dtypes
# Out:
# Game                         object
#  Start                       object
#  End                         object
#  Period                      object
#  Team                        object
#  Event                       object
#  Phase                       object
#  Offense System              object
#  Defense System              object
#  Assist                      object
#  Offense Player Number       object
#  Offense Player Name         object
#  Offense Player Position     object
#  Defense Player Number       object
#  Defense Player Name         object
#  Defense Player Position     object
#  Shooter Position            object
#  Shot Location               object
#  Home Team                   object
#  Visitor Team                object
#  Possession                   int64
#  Important                     bool
#  Game System                float64
# dtype: object

# %%
play_by_play_dataset[' Assist'] = play_by_play_dataset[' Assist'].astype('str')

# %%
arrojeria = ' 03-E. ARROJERIA'

# %%
play_by_play_dataset.at[40, ' Assist'] = arrojeria

# %% [markdown]
# Primera asistencia, añadidaplay_by_play_dataset[play_by_play_dataset['Start'] == '00:12:46']

# %%
play_by_play_dataset[play_by_play_dataset[' Start'] == ' 00:13:52']
# Out:
#                       Game      Start        End  Period       Team  Event  \
# 43  BERABERA vs GRANOLLERS   00:13:52   00:14:04      T1   BERABERA   GOAL
#
#           Phase  Offense System  Defense System  Assist  \
# 43   FAST_BREAK        EQUALITY             6:0
#
#     Offense Player Number  Offense Player Name  Offense Player Position  \
# 43                     15     15-M. ECHEVERRIA                       rw
#
#     Defense Player Number  Defense Player Name  Defense Player Position  \
# 43                      1        01-N. WIGGINS                       gk
#
#     Shooter Position  Shot Location  \
# 43          RIGHT_6M              1
#
#                                             Home Team  \
# 43   15-M. ECHEVERRIA, 14-M.CAVO, 42-C.POLONIO, 13...
#
#                                          Visitor Team   Possession  \
# 43   17-E.SOMAZA, 23-A.GONZALEZ, 22-P.MILAGROS, 14...           14
#
#      Important   Game System
# 43       False           NaN

# %%
play_by_play_dataset.at[43, ' Assist'] = arrojeria

# %%
play_by_play_dataset[play_by_play_dataset[' Start'] == ' 00:15:56']
# Out:
#                       Game      Start        End  Period       Team  Event  \
# 48  BERABERA vs GRANOLLERS   00:15:56   00:16:01      T1   BERABERA   GOAL
#
#           Phase  Offense System  Defense System  Assist  \
# 48   FAST_BREAK        EQUALITY             6:0
#
#     Offense Player Number  Offense Player Name  Offense Player Position  \
# 48                     42         42-C.POLONIO                       lp
#
#     Defense Player Number  Defense Player Name  Defense Player Position  \
# 48                      1        01-N. WIGGINS                       gk
#
#     Shooter Position  Shot Location  \
# 48         CENTER_6M              1
#
#                                             Home Team  \
# 48   15-M. ECHEVERRIA, 14-M.CAVO, 42-C.POLONIO, 13...
#
#                                          Visitor Team   Possession  \
# 48   17-E.SOMAZA, 23-A.GONZALEZ, 22-P.MILAGROS, 14...           16
#
#      Important   Game System
# 48       False           NaN

# %%
play_by_play_dataset.at[48, ' Assist'] = arrojeria

# %%
play_by_play_dataset[play_by_play_dataset[' Start'] == ' 00:17:36']
# Out:
#                       Game      Start        End  Period       Team  Event  \
# 52  BERABERA vs GRANOLLERS   00:17:36   00:17:52      T1   BERABERA   GOAL
#
#                   Phase  Offense System  Defense System  Assist  \
# 52   OFFENSE_POSITIONAL        EQUALITY             6:0
#
#     Offense Player Number  Offense Player Name  Offense Player Position  \
# 52                      4      04-M. FERNANDES                       lb
#
#     Defense Player Number  Defense Player Name  Defense Player Position  \
# 52                      1        01-N. WIGGINS                       gk
#
#     Shooter Position  Shot Location  \
# 52         CENTER_6M              1
#
#                                             Home Team  \
# 52   01-A.DIVA, 03-E. ARROJERIA, 04-M. FERNANDES, ...
#
#                                          Visitor Team   Possession  \
# 52   17-E.SOMAZA, 23-A.GONZALEZ, 22-P.MILAGROS, 14...           18
#
#      Important   Game System
# 52       False           NaN

# %%
play_by_play_dataset.at[52, ' Assist'] = arrojeria

# %%
play_by_play_dataset[play_by_play_dataset[' Start'] == ' 00:19:37']
# Out:
#                       Game      Start        End  Period       Team  Event  \
# 58  BERABERA vs GRANOLLERS   00:19:37   00:19:53      T1   BERABERA   GOAL
#
#                   Phase  Offense System  Defense System  Assist  \
# 58   OFFENSE_POSITIONAL        EQUALITY             6:0
#
#     Offense Player Number  Offense Player Name  Offense Player Position  \
# 58                      4      04-M. FERNANDES                       lb
#
#     Defense Player Number  Defense Player Name  Defense Player Position  \
# 58                      1        01-N. WIGGINS                       gk
#
#     Shooter Position  Shot Location  \
# 58           LEFT_6M              4
#
#                                             Home Team  \
# 58   01-A.DIVA, 03-E. ARROJERIA, 04-M. FERNANDES, ...
#
#                                          Visitor Team   Possession  \
# 58   17-E.SOMAZA, 23-A.GONZALEZ, 22-P.MILAGROS, 14...           20
#
#      Important   Game System
# 58       False           NaN

# %%
play_by_play_dataset.at[58, ' Assist'] = arrojeria

# %%
play_by_play_dataset[play_by_play_dataset[' Start'] == ' 00:31:42']
# Out:
#                       Game      Start        End  Period       Team  Event  \
# 93  BERABERA vs GRANOLLERS   00:31:42   00:32:11      T2   BERABERA   GOAL
#
#                   Phase  Offense System  Defense System  Assist  \
# 93   OFFENSE_POSITIONAL        EQUALITY             6:0
#
#     Offense Player Number  Offense Player Name  Offense Player Position  \
# 93                     18         18-E.KARSTEN                       rb
#
#     Defense Player Number  Defense Player Name  Defense Player Position  \
# 93                      1        01-N. WIGGINS                       gk
#
#     Shooter Position  Shot Location  \
# 93           LEFT_9M              2
#
#                                             Home Team  \
# 93   03-E. ARROJERIA, 01-A.DIVA, 13-L.HERNANDEZ, 4...
#
#                                          Visitor Team   Possession  \
# 93   23-A.GONZALEZ, 14-O. VEGUE, 01-N. WIGGINS, 22...           31
#
#      Important   Game System
# 93       False           NaN

# %%
play_by_play_dataset.at[93, ' Assist'] = arrojeria

# %%
play_by_play_dataset[play_by_play_dataset[' Start'] == ' 00:38:20']
# Out:
#                        Game      Start        End  Period       Team  Event  \
# 114  BERABERA vs GRANOLLERS   00:38:20   00:38:27      T2   BERABERA   GOAL
#
#              Phase     Offense System  Defense System  Assist  \
# 114   COUNTER_GOAL   SUPERIORITY-6vs5             6:0
#
#      Offense Player Number  Offense Player Name  Offense Player Position  \
# 114                     13       13-L.HERNANDEZ                       lb
#
#      Defense Player Number  Defense Player Name  Defense Player Position  \
# 114                     16           16-M. MERA                       gk
#
#      Shooter Position  Shot Location  \
# 114           LEFT_6M              3
#
#                                              Home Team  \
# 114   03-E. ARROJERIA, 01-A.DIVA, 13-L.HERNANDEZ, 4...
#
#                                           Visitor Team   Possession  \
# 114   23-A.GONZALEZ, 14-O. VEGUE, 16-M. MERA, 98-M....           39
#
#       Important   Game System
# ...

# %%
play_by_play_dataset.at[114, ' Assist'] = arrojeria

# %% [markdown]
# Ya se tienen todas las asistencias añadidas, se guarda el nuevo dataset.

# %%
play_by_play_dataset.to_csv('../../datasets/play-by-play-study/play_by_play_with_arrojeria_assists.csv', sep='\t')
