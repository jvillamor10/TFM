# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
PLAY_BY_PLAY_DATASET_FILE_DIR = 'Copia de playByplay-2023-05-10T20_05_08.442+02_00.csv'

# %%
play_by_play_dataset = pd.read_csv(PLAY_BY_PLAY_DATASET_FILE_DIR, sep='\t ')
# Out:
# /home/jvillamor10/.local/lib/python3.9/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
play_by_play_dataset
# Out:
#                        Game     Start       End Period        Team  \
# 0    BERABERA vs GRANOLLERS  00:00:00  00:00:00     T1  GRANOLLERS
# 1    BERABERA vs GRANOLLERS  00:00:00  00:00:36     T1  GRANOLLERS
# 2    BERABERA vs GRANOLLERS  00:00:36  00:00:45     T1  GRANOLLERS
# 3    BERABERA vs GRANOLLERS  00:00:45  00:00:55     T1    BERABERA
# 4    BERABERA vs GRANOLLERS  00:00:55  00:01:24     T1  GRANOLLERS
# ..                      ...       ...       ...    ...         ...
# 176  BERABERA vs GRANOLLERS  00:58:26  00:58:46     T2    BERABERA
# 177  BERABERA vs GRANOLLERS  00:58:46  00:58:56     T2  GRANOLLERS
# 178  BERABERA vs GRANOLLERS  00:58:56  00:59:11     T2  GRANOLLERS
# 179  BERABERA vs GRANOLLERS  00:59:11  00:59:43     T2    BERABERA
# 180  BERABERA vs GRANOLLERS  00:59:43  00:59:46     T2    BERABERA
#
#                 Event               Phase Offense System Defense System  \
# 0    FIRST_HALF_START  OFFENSE_POSITIONAL       EQUALITY            6:0
# ...

# %%
play_by_play_dataset['Event'].unique()
# Out:
# array(['FIRST_HALF_START', 'FOUL_RECEIVE', 'POST_OUT', 'LOST_BALL',
#        'GOAL', '7M_PROVOKE', 'SAVE', '7M_PROVOKE_SUSPENSION', '2_MIN',
#        'FIRST_HALF_END', 'SECOND_HALF_START', '2MIN_PROVOKE',
#        'SECOND_HALF_END'], dtype=object)
