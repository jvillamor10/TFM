# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/first-study/processed_dataset.csv',index_col=0)
df.head()
# Out:
#    seconds                     date  speed  hr  core_temperature        x  \
# 0    1.003  2023-04-23 18:10:38.770    0.0 NaN               NaN      NaN
# 1    1.101  2023-04-23 18:10:38.770    NaN NaN               NaN -11.3313
# 2    1.104  2023-04-23 18:10:38.770    0.0 NaN               NaN      NaN
# 3    1.110  2023-04-23 18:10:38.770    NaN NaN               NaN -14.0875
# 4    1.120  2023-04-23 18:10:38.770    NaN NaN               NaN -12.0969
#
#         y        z  raw_rr  filtered_rr  difference_rr  hr_rmssd  \
# 0     NaN      NaN     NaN          NaN            NaN       NaN
# 1 -3.5219 -23.8975     NaN          NaN            NaN       NaN
# 2     NaN      NaN     NaN          NaN            NaN       NaN
# 3 -1.5312 -24.6631     NaN          NaN            NaN       NaN
# 4 -0.7656 -25.5819     NaN          NaN            NaN       NaN
#
#    activity_load_2d  activity_load_3d
# 0               NaN               NaN
# 1               NaN               NaN
# ...

# %%
hr = df[['seconds','date','hr']]

# %%
hr = hr[hr['hr'].notnull()]

# %%
hr.to_csv('../../datasets/first-study/hr.csv')
